# %%
# TODO fix duplicated indices

import matplotlib.pyplot as plt
import torch

state = torch.load('./saves/tests/ops/causal_resize_m_to_t/state.pth')
def imshow(t):
    plt.imshow(t[0,0].cpu().numpy())
    plt.colorbar()
    plt.show()

imshow(state['tm'])
print('csr')
imshow(state['csr'])
print('dense')
imshow(state['dense'])
# Out:
# csr
# dense
